# %%
class Practice:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def get_info(self):
        print(f"My name is {self.name} and my age is {self.age}")


course = Practice("Minoo", 30)
course.get_info()
# Out:
# My name is Minoo and my age is 30
